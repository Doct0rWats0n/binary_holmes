# %%
import torch
from torch.utils.data import Dataset, DataLoader

class TextDataset(Dataset):
    def __init__(self, text, chunk_size, chunk_overlap):
        self.text = text
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap

        # Create overlapping sequences
        self.sequences = [text[i:i + chunk_size] for i in range(0, len(text) - chunk_size + 1, chunk_size - chunk_overlap)]

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        sequence = self.sequences[idx]
        # Convert characters to indices
        sequence_indices = [char_to_index[char] for char in sequence]

        # Convert to PyTorch tensor
        sequence_tensor = torch.tensor(sequence_indices, dtype=torch.long)

        return sequence_tensor

# %%
# Example usage
with open('file.c', 'r') as f:
    text = f.read()
char_to_index = {char: idx for idx, char in enumerate(set(text))}
index_to_char = {idx: char for char, idx in char_to_index.items()}

chunk_size = 100
chunk_overlap = 50

dataset = TextDataset(text, chunk_size, chunk_overlap)
dataloader = DataLoader(dataset, batch_size=len(dataset), shuffle=False)

print(dir(dataset))
print(dataset.sequences)
print("\n" * 50)
for batch in dataloader:
    print("Batch:\n")
    for sequence in batch:
        decoded_sequence = ''.join([index_to_char[idx.item()] for idx in sequence])
        print(decoded_sequence)
    print("-" * 20)
# Out:
# ['__add__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_is_protocol', 'chunk_overlap', 'chunk_size', 'sequences', 'text']
# ['#include "std_testcase.h"\n\n#include <wchar.h>\n\n#ifdef _WIN32\n#define COMMAND_INT_PATH L"%WINDIR%\\\\sy', 'def _WIN32\n#define COMMAND_INT_PATH L"%WINDIR%\\\\system32\\\\cmd.exe"\n#define COMMAND_INT L"cmd.exe"\n#d', 'stem32\\\\cmd.exe"\n#define COMMAND_INT L"cmd.exe"\n#define COMMAND_ARG1 L"/c"\n#define COMMAND_ARG2 L"di', 'efine COMMAND_ARG1 L"/c"\n#define COMMAND_ARG2 L"dir "\n#define COMMAND_ARG3 data\n#else /* NOT _WIN32 ', 'r "\n#define COMMAND_ARG3 data\n#else /* NOT _WIN32 */\n#include <unistd.h>\n#define COMMAND_INT_PATH L"', '*/\n#include <unistd.h>\n#define COMMAND_INT_PATH L"/bin/sh"\n#define COMMAND_INT L"sh"\n#define COMMAND', '/bin/sh"\n#define COMMAND_INT L"sh"\n#define COMMAND_ARG1 L"-c"\n#define COMMAND_ARG2 L"ls "\n#define CO', '_ARG1 L"-c"\n#define COMMAND_ARG2 L"ls "\n#define COMMAND_ARG3 data\n#endif\n\n#ifdef _WIN32\n#include <wi', 'MMAND_ARG3 data\n#endif\n\n#ifdef _WIN32\n#include <winsock2.h>\n#include <windows.h>\n#include <direct.h>', 'nsock2.h>\n#include <windows.h>\n#include <direct.h>\n#pragma comment(lib, "ws2_32") /* include ws2_32.', '\n#pragma comment(lib, "ws2_32") /* include ws2_32.lib when linking */\n#define CLOSE_SOCKET closesock', 'lib when linking */\n#define CLOSE_SOCKET closesocket\n#else\n#include <sys/types.h>\n#include <sys/sock', 'et\n#else\n#include <sys/types.h>\n#include <sys/socket.h>\n#include <netinet/in.h>\n#include <arpa/inet.', 'et.h>\n#include <netinet/in.h>\n#include <arpa/inet.h>\n#define INVALID_SOCKET -1\n#define SOCKET_ERROR ', 'h>\n#define INVALID_SOCKET -1\n#define SOCKET_ERROR -1\n#define CLOSE_SOCKET close\n#define SOCKET int\n#', '-1\n#define CLOSE_SOCKET close\n#define SOCKET int\n#endif\n\n#define TCP_PORT 27015\n#define LISTEN_BACKL', 'endif\n\n#define TCP_PORT 27015\n#define LISTEN_BACKLOG 5\n\n#include <process.h>\n\ntypedef struct _CWE78_', 'OG 5\n\n#include <process.h>\n\ntypedef struct _CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_sp', 'OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType\n{\n    wchar_t * structFirst;\n}', 'awnvp_67_structType\n{\n    wchar_t * structFirst;\n} CWE78_OS_Command_Injection__wchar_t_listen_socket', ' CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType;\n\n#ifndef OMITBAD\n\n/* b', '_w32_spawnvp_67_structType;\n\n#ifndef OMITBAD\n\n/* bad function declaration */\nvoid CWE78_OS_Command_I', 'ad function declaration */\nvoid CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67b_ba', 'njection__wchar_t_listen_socket_w32_spawnvp_67b_badSink(CWE78_OS_Command_Injection__wchar_t_listen_s', 'dSink(CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType myStruct);\n\nvoid C', 'ocket_w32_spawnvp_67_structType myStruct);\n\nvoid CWE78_OS_Command_Injection__wchar_t_listen_socket_w', 'WE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_bad()\n{\n    wchar_t * data;\n    CWE7', '32_spawnvp_67_bad()\n{\n    wchar_t * data;\n    CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_', '8_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType myStruct;\n    wchar_t dataBu', 'spawnvp_67_structType myStruct;\n    wchar_t dataBuffer[100] = COMMAND_ARG2;\n    data = dataBuffer;\n ', 'ffer[100] = COMMAND_ARG2;\n    data = dataBuffer;\n    {\n#ifdef _WIN32\n        WSADATA wsaData;\n      ', '   {\n#ifdef _WIN32\n        WSADATA wsaData;\n        int wsaDataInit = 0;\n#endif\n        int recvResu', '  int wsaDataInit = 0;\n#endif\n        int recvResult;\n        struct sockaddr_in service;\n        wc', 'lt;\n        struct sockaddr_in service;\n        wchar_t *replace;\n        SOCKET listenSocket = INVA', 'har_t *replace;\n        SOCKET listenSocket = INVALID_SOCKET;\n        SOCKET acceptSocket = INVALID_', 'LID_SOCKET;\n        SOCKET acceptSocket = INVALID_SOCKET;\n        size_t dataLen = wcslen(data);\n   ', 'SOCKET;\n        size_t dataLen = wcslen(data);\n        do\n        {\n#ifdef _WIN32\n            if (WS', '     do ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Batch:
#
# #include "std_testcase.h"
#
# #include <wchar.h>
#
# #ifdef _WIN32
# #define COMMAND_INT_PATH L"%WINDIR%\\sy
# def _WIN32
# #define COMMAND_INT_PATH L"%WINDIR%\\system32\\cmd.exe"
# #define COMMAND_INT L"cmd.exe"
# #d
# stem32\\cmd.exe"
# #define COMMAND_INT L"cmd.exe"
# #define COMMAND_ARG1 L"/c"
# #define COMMAND_ARG2 L"di
# efine COMMAND_ARG1 L"/c"
# #define COMMAND_ARG2 L"dir "
# #define COMMAND_ARG3 data
# #else /* NOT _WIN32
# r "
# #define COMMAND_ARG3 data
# #else /* NOT _WIN32 */
# #include <unistd.h>
# #define COMMAND_INT_PATH L"
# */
# #include <unistd.h>
# #define COMMAND_INT_PATH L"/bin/sh"
# #define COMMAND_INT L"sh"
# #define COMMAND
# /bin/sh"
# #define COMMAND_INT L"sh"
# #define COMMAND_ARG1 L"-c"
# #define COMMAND_ARG2 L"ls "
# #define CO
# _ARG1 L"-c"
# #define COMMAND_ARG2 L"ls "
# #define COMMAND_ARG3 data
# #endif
#
# #ifdef _WIN32
# #include <wi
# MMAND_ARG3 data
# #endif
#
# #ifdef _WIN32
# #include <winsock2.h>
# #include <windows.h>
# #include <direct.h>
# nsock2.h>
# #include <windows.h>
# #include <direct.h>
# #pragma comment(lib, "ws2_32") /* include ws2_32.
#
# #pragma comment(lib, "ws2_32") /* include ws2_32.lib when linking */
# #define CLOSE_SOCKET closesock
# lib when linking */
# #define CLOSE_SOCKET closesocket
# #else
# #include <sys/types.h>
# #include <sys/sock
# et
# #else
# #include <sys/types.h>
# #include <sys/socket.h>
# #include <netinet/in.h>
# #include <arpa/inet.
# et.h>
# #include <netinet/in.h>
# #include <arpa/inet.h>
# #define INVALID_SOCKET -1
# #define SOCKET_ERROR
# h>
# #define INVALID_SOCKET -1
# #define SOCKET_ERROR -1
# #define CLOSE_SOCKET close
# #define SOCKET int
# #
# -1
# #define CLOSE_SOCKET close
# #define SOCKET int
# #endif
#
# #define TCP_PORT 27015
# #define LISTEN_BACKL
# endif
#
# #define TCP_PORT 27015
# #define LISTEN_BACKLOG 5
#
# #include <process.h>
#
# typedef struct _CWE78_
# OG 5
#
# #include <process.h>
#
# typedef struct _CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_sp
# OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType
# {
#     wchar_t * structFirst;
# }
# awnvp_67_structType
# {
#     wchar_t * structFirst;
# } CWE78_OS_Command_Injection__wchar_t_listen_socket
#  CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType;
#
# #ifndef OMITBAD
#
# /* b
# _w32_spawnvp_67_structType;
#
# #ifndef OMITBAD
#
# /* bad function declaration */
# void CWE78_OS_Command_I
# ad function declaration */
# void CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67b_ba
# njection__wchar_t_listen_socket_w32_spawnvp_67b_badSink(CWE78_OS_Command_Injection__wchar_t_listen_s
# dSink(CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType myStruct);
#
# void C
# ocket_w32_spawnvp_67_structType myStruct);
#
# void CWE78_OS_Command_Injection__wchar_t_listen_socket_w
# WE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_bad()
# {
#     wchar_t * data;
#     CWE7
# 32_spawnvp_67_bad()
# {
#     wchar_t * data;
#     CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_
# 8_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType myStruct;
#     wchar_t dataBu
# spawnvp_67_structType myStruct;
#     wchar_t dataBuffer[100] = COMMAND_ARG2;
#     data = dataBuffer;
#
# ffer[100] = COMMAND_ARG2;
#     data = dataBuffer;
#     {
# #ifdef _WIN32
#         WSADATA wsaData;
#
#    {
# #ifdef _WIN32
#         WSADATA wsaData;
#         int wsaDataInit = 0;
# #endif
#         int recvResu
#   int wsaDataInit = 0;
# #endif
#         int recvResult;
#         struct sockaddr_in service;
#         wc
# lt;
#         struct sockaddr_in service;
#         wchar_t *replace;
#         SOCKET listenSocket = INVA
# har_t *replace;
#         SOCKET listenSocket = INVALID_SOCKET;
#         SOCKET acceptSocket = INVALID_
# LID_SOCKET;
#         SOCKET acceptSocket = INVALID_SOCKET;
#         size_t dataLen = wcslen(data);
#
# SOCKET;
#         size_t dataLen = wcslen(data);
#         do
#         {
# #ifdef _WIN32
#             if (WS
#      do
#         {
# #ifdef _WIN32
#             if (WSAStartup(MAKEWORD(2,2), &wsaData) != NO_ERROR)
#
# AStartup(MAKEWORD(2,2), &wsaData) != NO_ERROR)
#             {
#                 break;
#             }
#
#          {
#                 break;
#             }
#             wsaDataInit = 1;
# #endif
#             /* P
#           wsaDataInit = 1;
# #endif
#             /* POTENTIAL FLAW: Read data using a listen socket */
#
# OTENTIAL FLAW: Read data using a listen socket */
#             listenSocket = socket(AF_INET, SOCK_ST
#             listenSocket = socket(AF_INET, SOCK_STREAM, IPPROTO_TCP);
#             if (listenSocket =
# REAM, IPPROTO_TCP);
#             if (listenSocket == INVALID_SOCKET)
#             {
#                 br
# = INVALID_SOCKET)
#             {
#                 break;
#             }
#             memset(&service, 0,
# eak;
#             }
#             memset(&service, 0, sizeof(service));
#             service.sin_family
#  sizeof(service));
#             service.sin_family = AF_INET;
#             service.sin_addr.s_addr = I
# = AF_INET;
#             service.sin_addr.s_addr = INADDR_ANY;
#             service.sin_port = htons(TC
# NADDR_ANY;
#             service.sin_port = htons(TCP_PORT);
#             if (bind(listenSocket, (struc
# P_PORT);
#             if (bind(listenSocket, (struct sockaddr*)&service, sizeof(service)) == SOCKET_E
# t sockaddr*)&service, sizeof(service)) == SOCKET_ERROR)
#             {
#                 break;
#
# RROR)
#             {
#                 break;
#             }
#             if (listen(listenSocket, LISTEN
#      }
#             if (listen(listenSocket, LISTEN_BACKLOG) == SOCKET_ERROR)
#             {
#
# _BACKLOG) == SOCKET_ERROR)
#             {
#                 break;
#             }
#             acceptSock
#        break;
#             }
#             acceptSocket = accept(listenSocket, NULL, NULL);
#
# et = accept(listenSocket, NULL, NULL);
#             if (acceptSocket == SOCKET_ERROR)
#             {
#
#  if (acceptSocket == SOCKET_ERROR)
#             {
#                 break;
#             }
#             /*
#                break;
#             }
#             /* Abort on error or the connection was closed */
#
#  Abort on error or the connection was closed */
#             recvResult = recv(acceptSocket, (char *)
#           recvResult = recv(acceptSocket, (char *)(data + dataLen), sizeof(wchar_t) * (100 - dataLen
# (data + dataLen), sizeof(wchar_t) * (100 - dataLen - 1), 0);
#             if (recvResult == SOCKET_ER
#  - 1), 0);
#             if (recvResult == SOCKET_ERROR || recvResult == 0)
#             {
#
# ROR || recvResult == 0)
#             {
#                 break;
#             }
#             /* Append nul
#     break;
#             }
#             /* Append null terminator */
#             data[dataLen + recvRes
# l terminator */
#             data[dataLen + recvResult / sizeof(wchar_t)] = L'\0';
#             /* Eli
# ult / sizeof(wchar_t)] = L'\0';
#             /* Eliminate CRLF */
#             replace = wcschr(data,
# minate CRLF */
#             replace = wcschr(data, L'\r');
#             if (replace)
#             {
#
# L'\r');
#             if (replace)
#             {
#                 *replace = L'\0';
#             }
#
#              *replace = L'\0';
#             }
#             replace = wcschr(data, L'\n');
#
#        replace = wcschr(data, L'\n');
#             if (replace)
#             {
#                 *replac
# if (replace)
#             {
#                 *replace = L'\0';
#             }
#         }
#         while (
# e = L'\0';
#             }
#         }
#         while (0);
#         if (listenSocket != INVALID_SOCKET)
#
# 0);
#         if (listenSocket != INVALID_SOCKET)
#         {
#             CLOSE_SOCKET(listenSocket);
#
#       {
#             CLOSE_SOCKET(listenSocket);
#         }
#         if (acceptSocket != INVALID_SOCKET
#       }
#         if (acceptSocket != INVALID_SOCKET)
#         {
#             CLOSE_SOCKET(acceptSocket)
# )
#         {
#             CLOSE_SOCKET(acceptSocket);
#         }
# #ifdef _WIN32
#         if (wsaDataInit)
# ;
#         }
# #ifdef _WIN32
#         if (wsaDataInit)
#         {
#             WSACleanup();
#         }
# #en
#
#         {
#             WSACleanup();
#         }
# #endif
#     }
#     myStruct.structFirst = data;
#     CWE
# dif
#     }
#     myStruct.structFirst = data;
#     CWE78_OS_Command_Injection__wchar_t_listen_socket_w32
# 78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67b_badSink(myStruct);
# }
#
# #endif /* OMITB
# _spawnvp_67b_badSink(myStruct);
# }
#
# #endif /* OMITBAD */
#
# #ifndef OMITGOOD
#
# /* goodG2B uses the GoodS
# AD */
#
# #ifndef OMITGOOD
#
# /* goodG2B uses the GoodSource with the BadSink */
# void CWE78_OS_Command_In
# ource with the BadSink */
# void CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67b_goo
# jection__wchar_t_listen_socket_w32_spawnvp_67b_goodG2BSink(CWE78_OS_Command_Injection__wchar_t_liste
# dG2BSink(CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType myStruct);
#
# sta
# n_socket_w32_spawnvp_67_structType myStruct);
#
# static void goodG2B()
# {
#     wchar_t * data;
#     CWE78
# tic void goodG2B()
# {
#     wchar_t * data;
#     CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_s
# _OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_structType myStruct;
#     wchar_t dataBuf
# pawnvp_67_structType myStruct;
#     wchar_t dataBuffer[100] = COMMAND_ARG2;
#     data = dataBuffer;
#
# fer[100] = COMMAND_ARG2;
#     data = dataBuffer;
#     /* FIX: Append a fixed string to data (not user
#   /* FIX: Append a fixed string to data (not user / external input) */
#     wcscat(data, L"*.*");
#
# / external input) */
#     wcscat(data, L"*.*");
#     myStruct.structFirst = data;
#     CWE78_OS_Command
#  myStruct.structFirst = data;
#     CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67b_
# _Injection__wchar_t_listen_socket_w32_spawnvp_67b_goodG2BSink(myStruct);
# }
#
# void CWE78_OS_Command_In
# goodG2BSink(myStruct);
# }
#
# void CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_good
# jection__wchar_t_listen_socket_w32_spawnvp_67_good()
# {
#     goodG2B();
# }
#
# #endif /* OMITGOOD */
#
# /* B
# ()
# {
#     goodG2B();
# }
#
# #endif /* OMITGOOD */
#
# /* Below is the main(). It is only used when building
# elow is the main(). It is only used when building this testcase on
#  * its own for testing or for bui
# this testcase on
#  * its own for testing or for building a binary to use in testing binary
#  * analysi
# lding a binary to use in testing binary
#  * analysis tools. It is not used when compiling all the tes
# s tools. It is not used when compiling all the testcases as one
#  * application, which is how source
# tcases as one
#  * application, which is how source code analysis tools are tested.
#  */
#
# #ifdef INCLUD
# code analysis tools are tested.
#  */
#
# #ifdef INCLUDEMAIN
#
# int main(int argc, char * argv[])
# {
#     /*
# EMAIN
#
# int main(int argc, char * argv[])
# {
#     /* seed randomness */
#     srand( (unsigned)time(NULL)
# seed randomness */
#     srand( (unsigned)time(NULL) );
# #ifndef OMITGOOD
#     printLine("Calling good()
#  );
# #ifndef OMITGOOD
#     printLine("Calling good()...");
#     CWE78_OS_Command_Injection__wchar_t_lis
# ...");
#     CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_good();
#     printLine("F
# ten_socket_w32_spawnvp_67_good();
#     printLine("Finished good()");
# #endif /* OMITGOOD */
# #ifndef OM
# inished good()");
# #endif /* OMITGOOD */
# #ifndef OMITBAD
#     printLine("Calling bad()...");
#     CWE78
# ITBAD
#     printLine("Calling bad()...");
#     CWE78_OS_Command_Injection__wchar_t_listen_socket_w32_s
# _OS_Command_Injection__wchar_t_listen_socket_w32_spawnvp_67_bad();
#     printLine("Finished bad()");
#
# --------------------

# %%
len(dataset)
# Out:
# 111

# %%
dataset.sequences[50], dataset.sequences[51]
# Out:
# ('t sockaddr*)&service, sizeof(service)) == SOCKET_ERROR)\n            {\n                break;\n       ',
#  'RROR)\n            {\n                break;\n            }\n            if (listen(listenSocket, LISTEN')
